# %%
from libs.mysql import SQL

engine = "usadmin_PJA_ISJ:20pja!isj18@192.168.52.218/PJA_ISJ"
sql = SQL(engine, driver="mysql")
sql.get_tables_names()
# Out:
# Tabla: BuenosAiresMP_ClaseDelito
# Tabla: BuenosAiresMP_ClaseDependencia
# Tabla: BuenosAiresMP_DepartamentoJudicial
# Tabla: BuenosAiresMP_Dependencia
# Tabla: BuenosAiresMP_Listado1
# Tabla: BuenosAiresMP_Listado1_viejo
# Tabla: BuenosAiresMP_Listado2
# Tabla: BuenosAiresMP_Listado2_viejo
# Tabla: BuenosAiresMP_Listado3
# Tabla: BuenosAiresMP_Listado3_viejo
# Tabla: BuenosAiresMP_Listado4
# Tabla: BuenosAiresMP_Listado4_viejo
# Tabla: CabaPJ_tabla3
# Tabla: CabaPJ_tabla5
# Tabla: CabaPJ_tabla5_1
# Tabla: CabaPJ_tabla6
# Tabla: CabaPJ_tabla6_2
# Tabla: ChacoMP_Listado2
# Tabla: ChubutMP_Listado1
# Tabla: ChubutMP_Listado1_vieja
# Tabla: ChubutMP_Listado2
# Tabla: ChubutMP_Listado2_vieja
# Tabla: ChubutMP_Listado3
# Tabla: ChubutMP_Listado3_vieja
# Tabla: ChubutMP_Listado4
# Tabla: ChubutMP_Listado4_vieja
# Tabla: ChubutMP_datosPrimarios_decisiones
# Tabla: ChubutMP_datosPrimarios_denuncias
# Tabla: ChubutMP_tabla1
# Tabla: ChubutMP_tabla1_1
# Tabla: ChubutMP_tabla2
# ...
